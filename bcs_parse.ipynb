# %%
import pandas as pd
import re
import os
import bs4
import bz2
import datetime
import dateparser
import locale
import time
from poptimizer.data.adapters.html.parser import _get_html

# %%
async def get_html(url_source: str, html_path: str):
    downloaded = False
    if not os.path.exists(html_path + '.bz2'):
        print('download:', url_source)
        html = await _get_html(url_source)
        soup = bs4.BeautifulSoup(html, "lxml")
        downloaded = True
        # cache
        with bz2.open(html_path + '.bz2', 'wb') as f:
            f.write(soup.prettify(encoding='utf-8'))
            
    if not downloaded:
        with bz2.open(html_path + '.bz2', 'rb') as f:
            soup = bs4.BeautifulSoup(f.read().decode(encoding='utf-8'), "lxml")
    return soup

# %%
base_path = os.path.join('bcs','htmls')
os.makedirs(base_path, exist_ok=True)

# %%
url_source = 'https://bcs-express.ru/dividednyj-kalendar?year=2020'
html_path = os.path.join(base_path, '_divs.html')
soup = await get_html(url_source, html_path)

# %%
async def get_ticker(ticker: str):
    url_source = f'https://bcs-express.ru/kotirovki-i-grafiki/{ticker.lower()}'
    html_path = os.path.join(base_path, ticker.lower() + datetime.datetime.today().strftime('_%Y-%m-%d.html'))
    return await get_html(url_source, html_path)

# %%
rows = soup.find_all("select", {'class': 'js-filter-select-control', 'name':'emitent'})
data = set()
for r in rows:
    for o in r.find_all('option'):
        val = o.get('value') # might be None
        if val:
            val = [s.upper() for s in val.strip().split(',')]
            tick = val[0]
            operating_mode = val[1]
            name = o.contents[0].strip()
            data.add((tick, operating_mode, name))
ticks_df = pd.DataFrame.from_records(data=list(data), columns=['ticker', 'operating_mode', 'company_name'])
ticks_df.set_index('ticker', inplace=True)
ticks_df
# Out:
#        operating_mode   company_name
# ticker
# NKSH             TQBR     Нижкамшина
# DSKY             TQBR    Детский Мир
# MRKP             TQBR        МРСК ЦП
# RSTI             TQBR        Россети
# YNDX             TQBR         Яндекс
# ...               ...            ...
# KRSB             TQBR       КрасэЭсб
# MRKV             TQBR     МРСК Волги
# SIBN             TQBR  Газпром нефть
# FLOT             TQBR     Совкомфлот
# ISKJ             TQBR           ИСКЧ
#
# [284 rows x 2 columns]

# %%
def parse_head(used_body):
    cols = ['actual_time', 'actual_price', 
            'pct_change_tod', 'open', 'close_prev_day', 'volume', 
            'max_price_ytd', 'min_price_ytd', 'pct_change_ytd',
            'pct_change_month', 'pct_change_year']
    data = []
    
    default_loc = locale.getlocale()
    
    head = used_body.find("div", {'class': 'quote-head js-quote-head'})
    actual_time = head.find("div", {'class': 'quote-head__date js-time'}).contents[0].strip()
    
    locale.setlocale( locale.LC_ALL, ('Russian_Russia', '1251') )
    
    actual_time = dateparser.parse(actual_time, date_formats=['%H:%M  %d %B %Y'], languages=['ru'])
    data.append(actual_time)
    actual_price = head.find("div", {'class': 'quote-head__price-value js-quote-head-price js-price-close'}).contents[0].strip()
    
    locale.setlocale( locale.LC_ALL, 'ru_RU.UTF-8' )
    
    actual_price = locale.atof(actual_price)
    data.append(actual_price)
    tables = head.find_all("div", {'class': 'quote-head__table'})

    for t in tables:
        rows = t.find_all('div', {'class': re.compile('quote-head__table-row')})
        for r in rows:
            cells = r.find_all('div', {'class': re.compile('quote-head__table-cell.*')})
            for i in range(len(cells)):
                span = cells[i].find('span', {'class': re.compile('js-profit-percent')})
                if span:
                    cells[i] = span
            try:
                row_data = locale.atof(cells[1].contents[0].strip().split('\n')[0].replace('%', ''))
            except (IndexError, ValueError):
                print('Error:', cells)
                row_data = None
            data.append(row_data)
    df = pd.DataFrame(data=[data], columns=cols)
    
    locale.setlocale( locale.LC_ALL, default_loc )
    return df

# %%
fmt_re = re.compile(r'<strong>|</strong>|<ol>|</ol><li>|</li>|<o>|</o>|<br>|</br>|<br/>|<li>|</li>|<ul>|</ul>|<p>|</p>|\n')

def clear_format(contents):
    cont = []
    for c in contents:
        cont.extend(list(filter(None, [row.strip() for row in re.split(fmt_re, str(c))])))
    return ' | '.join(cont)

def parse_info(used_body):
    em_info = used_body.find("div", {'class': 'quote-emitent__info'})
    em_info_items = em_info.find_all("div", {'class': 'quote-emitent__data-item'})
    cols = []
    values = []
    for it in em_info_items:
        cols.append(it.find("div", {'class': 'quote-emitent__data-title'}).contents[0].strip())
        v = it.find("div", {'class': 'quote-emitent__data-value'}).contents[0].strip()
        try:
            v = locale.atof(v)
        except ValueError:
            pass
        values.append(v)

    cols.append(em_info.find("h2", {'class': 'quote-emitent__description-title'}).contents[0].strip())
    text = em_info.find("div", {'class': 'quote-emitent__description-text'})
    if text.find('div'):
        text = ' '.join([clear_format(d.contents) for d in text.find_all('div')])
    else:
        text = clear_format(text.contents)
    values.append(text)
    df = pd.DataFrame(data=[values], columns=cols)
    return df

# %%
def parse_divs(used_body):
    interesting = [
               re.compile('dividends-table__cell _title.*'),
               re.compile('dividends-table__cell _last-day.*'),
               re.compile('dividends-table__cell _close-date.*'),
               re.compile('dividends-table__cell _value.*'),
               re.compile('dividends-table__cell _price.*'),
               re.compile('dividends-table__cell _profit.*')
              ]
    divs = used_body.find("div", {'class': 'dividends-table js-div-table'})
    rows = divs.find_all("div", {'class': 'dividends-table__row _item'})
    data = set()
    for i, r in enumerate(rows):
        row_data = []
        for c in interesting:
            d = r.find("div", {'class': c})
            spans = d.find_all('span')
            if spans:
                d = spans[0]
            v = d.contents[0].strip('—%\n ')
            try:
                v = locale.atof(v)
            except ValueError:
                try:
                    v = datetime.datetime.strptime(v, '%d.%m.%Y')
                except ValueError:
                    pass
            row_data.append(v)
        data.add(tuple(row_data))
    divs_df = pd.DataFrame.from_records(data=list(data), columns=['company_name_period', 
                                                                  'last_day_to_buy', 'close_date',
                                                                  'value', 'price', 'profit_pct'])
    return divs_df

# %%
def save_to_excel(filename, dfs):
    # Given a dict of dataframes, for example:
    # dfs = {'gadgets': df_gadgets, 'widgets': df_widgets}
    writer = pd.ExcelWriter(filename, engine='xlsxwriter')
    for sheetname, df in dfs.items():  # loop through `dict` of dataframes
        df.to_excel(writer, sheet_name=sheetname)  # send df to writer
        worksheet = writer.sheets[sheetname]  # pull worksheet object
        for idx, col in enumerate(df.columns):  # loop through all columns
            series = df[col]
            max_len = series.astype(str).map(len).max() + 1
            worksheet.set_column(idx + 1, idx + 1, max_len)  # set column width
    writer.save()

# %%
sleep = 1

heads = []
infos = []
divs = []
for t in ticks_df.index:
    print(t)
    
    downloaded = False
    while not downloaded:
        try:
            soup = await get_ticker(t)
            downloaded = True
        except ClientPayloadError:
            print(f'Sleep for {sleep} sec')
            time.sleep(sleep)
    
    used_body = soup.find("div", {'class': 'page-grid__container-left'})
    
    head = parse_head(used_body)
    head['TICKER'] = t
    heads.append(head)
    
    
    info = parse_info(used_body)
    info['TICKER'] = t
    infos.append(info)
    
    try:
        div = parse_divs(used_body)
        div['TICKER'] = t
        divs.append(div)
    except AttributeError:
        print('Dividends not found')
        
infos = pd.concat(infos).set_index('TICKER').sort_index()
heads = pd.concat(heads).set_index('TICKER').sort_index()
divs = pd.concat(divs).sort_values(['TICKER', 'close_date', 'company_name_period']).set_index('TICKER')
# Out:
# NKSH
# Dividends not found
# DSKY
# MRKP
# RSTI
# YNDX
# Dividends not found
# MOBB
# Dividends not found
# KBSB
# KUNF
# Error: [<div class="quote-head__table-cell">
#                закрытие предыдущего дня
#               </div>, <div class="quote-head__table-cell">
#                -
#               </div>]
# Error: [<div class="quote-head__table-cell">
#                  макс. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Error: [<div class="quote-head__table-cell">
#                  мин. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# PMSBP
# PLSM
# Dividends not found
# KTSB
# Dividends not found
# USBN
# MAGN
# NPOF
# Dividends not found
# MGTSP
# TASBP
# Dividends not found
# TANL
# Dividends not found
# SPB
# Error: [<div class="quote-head__table-cell">
#                закрытие предыдущего дня
#               </div>, <div class="quote-head__table-cell">
#                -
#               </div>]
# Error: [<div class="quote-head__table-cell">
#                  макс. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Error: [<div class="quote-head__table-cell">
#                  мин. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Dividends not found
# TGKDP
# MAGEP
# CNTL
# RLMN
# VRSBP
# TRMK
# RGSS
# Dividends not found
# TRNFP
# TGKD
# ROST
# Dividends not found
# VRSB
# TORS
# GAZP
# URKZ
# IDVP
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# GAZA
# RTSB
# MISBP
# TGKN
# JNOS
# TATN
# KZOSP
# MGVM
# Dividends not found
# RBCM
# Dividends not found
# MGTS
# CHKZ
# BSPB
# VTBR
# KSGR
# Error: [<div class="quote-head__table-cell">
#                закрытие предыдущего дня
#               </div>, <div class="quote-head__table-cell">
#                -
#               </div>]
# Error: [<div class="quote-head__table-cell">
#                  макс. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Error: [<div class="quote-head__table-cell">
#                  мин. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# TTLK
# GCHE
# GAZS
# Dividends not found
# GMKN
# KGKCP
# BLNG
# MSRS
# SZPR
# Dividends not found
# LKOH
# CHMK
# MUGSP
# Dividends not found
# DIXY
# ROLO
# Dividends not found
# MRKY
# VLHZ
# ROSN
# VGSBP
# Dividends not found
# RUSP
# WTCMP
# KTSBP
# Dividends not found
# YAKG
# TGKA
# ETLN
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# PHOR
# OMSH
# Dividends not found
# SARE
# GRNT
# DZRDP
# CBOM
# KUZB
# IGSTP
# Dividends not found
# OGKB
# RTKMP
# VGSB
# Dividends not found
# TATNP
# MVID
# NSVZ
# Dividends not found
# UNKL
# Dividends not found
# KMTZ
# Error: [<div class="quote-head__table-cell">
#                закрытие предыдущего дня
#               </div>, <div class="quote-head__table-cell">
#                -
#               </div>]
# Error: [<div class="quote-head__table-cell">
#                  макс. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Error: [<div class="quote-head__table-cell">
#                  мин. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# PAZA
# Dividends not found
# UTAR
# BANE
# UWGN
# FESH
# Dividends not found
# VZRZ
# MRKC
# KRKN
# SNGS
# LIFE
# ZMZNP
# Dividends not found
# TGKB
# KROTP
# RUSI
# Dividends not found
# RUGR
# Dividends not found
# BISVP
# MTLR
# KRKNP
# ACKO
# DIOD
# VJGZP
# NKNC
# ELTZ
# Dividends not found
# SVAV
# LNZL
# UNAC
# DZRD
# LNZLP
# HALS
# Dividends not found
# KOGK
# GTLC
# AKRN
# APTK
# Dividends not found
# VJGZ
# GTRK
# INGR
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# VDSB
# RNFT
# Dividends not found
# TUZA
# Dividends not found
# LNTA
# Dividends not found
# ASSB
# TASB
# Dividends not found
# MSTT
# ENRU
# MRSB
# QIWI
# STSB
# MSST
# Dividends not found
# LSNGP
# LVHK
# ABRD
# MOEX
# CNTLP
# YRSB
# Dividends not found
# UKUZ
# JNOSP
# EELT
# Dividends not found
# ENPG
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# GAZT
# Dividends not found
# KRSBP
# MTLRP
# MTSS
# IRAO
# SELG
# STSBP
# YKEN
# KGKC
# TCSG
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# DVEC
# GAZAP
# MAGE
# DASB
# Dividends not found
# MUGS
# Dividends not found
# ROSB
# Dividends not found
# MRKK
# AVAN
# ARSA
# NFAZ
# Dividends not found
# RZSB
# PRFN
# Dividends not found
# GAZC
# Dividends not found
# OBUV
# HYDR
# IRGZ
# ALRS
# POGR
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# KMEZ
# Dividends not found
# RSTIP
# ZMZN
# Dividends not found
# PMSB
# RLMNP
# FTRE
# Dividends not found
# SAREP
# KBTK
# NLMK
# SFIN
# SELGP
# WTCM
# VSMO
# AFLT
# KRKO
# Dividends not found
# RTKM
# RASP
# NKHP
# AFKS
# KCHE
# Dividends not found
# CHEP
# UCSS
# Dividends not found
# TUCH
# Dividends not found
# YRSBP
# Dividends not found
# KZOS
# PRMB
# KRKOP
# Dividends not found
# AGRO
# RTGZ
# Dividends not found
# BISV
# MISB
# MRKS
# RKKE
# Dividends not found
# OMZZP
# KAZTP
# UPRO
# HIMCP
# NAUK
# MSNG
# ZILL
# Dividends not found
# HIMC
# Dividends not found
# NMTP
# SAGO
# TRCN
# LSNG
# RTSBP
# MERF
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# SBER
# FEES
# CHGZ
# Dividends not found
# ZVEZ
# Dividends not found
# IRKT
# MFGS
# KLSB
# LPSB
# Dividends not found
# TGKBP
# PRTK
# GEMA
# MRKU
# AMEZ
# BELU
# RUAL
# MFGSP
# ALBK
# YKENP
# KROT
# VZRZP
# IGST
# Dividends not found
# POLY
# NKNCP
# VSYD
# Dividends not found
# NVTK
# CHMF
# HHRU
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# MGNT
# KMAZ
# VSYDP
# Dividends not found
# ALNU
# MAIL
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# SNGSP
# CLSBP
# BANEP
# ODVA
# Dividends not found
# RDRB
# TNSE
# Error: [<div class="quote-head__table-cell">
#                закрытие предыдущего дня
#               </div>, <div class="quote-head__table-cell">
#                -
#               </div>]
# Error: [<div class="quote-head__table-cell">
#                  макс. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Error: [<div class="quote-head__table-cell">
#                  мин. цена
#                 </div>, <div class="quote-head__table-cell">
# </div>]
# Dividends not found
# TGKO
# Dividends not found
# TORSP
# PLZL
# CLSB
# NNSBP
# BRZL
# Dividends not found
# SIBG
# Dividends not found
# MGNZ
# CHZN
# Dividends not found
# KAZT
# OPIN
# KCHEP
# Dividends not found
# ARMD
# Dividends not found
# KUBE
# SLEN
# Dividends not found
# PIKK
# SAGOP
# SBERP
# ENPL
# NNSB
# LSRG
# MRKZ
# KRSB
# MRKV
# SIBN
# FLOT
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Error: [<div class="quote-head__table-cell">
#                  изменение
#                 </div>, <div class="quote-head__table-cell">
#                  -
#                 </div>]
# Dividends not found
# ISKJ
# Dividends not found

# %%
save_to_excel('bcs/bcs.xlsx', {'info': infos, 'state': heads, 'dividends': divs})

# %%
infos
# Out:
#               Акция   Номинал free-float                 Полное название  \
# TICKER
# ABRD    Абрау-Дюрсо         1          -                  АбрауДюрсо ОАО
# ACKO           АСКО         -          -                            АСКО
# AFKS        Система      0.09         33            АФК "Система" ОАО ао
# AFLT       Аэрофлот         1         41                  ПАО «Аэрофлот»
# AGRO       AGRO-гдр         0          -                        AGRO-гдр
# ...             ...       ...        ...                             ...
# YRSBP    ТНСэнЯр ап         1          -    Ярославская сбыт.комп.ОАО ап
# ZILL            ЗИЛ  1 000,00          -   Завод им. И.А.Лихачева ОАО ао
# ZMZN            ЗМЗ         1          -    Заволжский мотор.з-д(ОАО) ао
# ZMZNP        ЗМЗ ап         1          -  Заволжский мотор.завод (ОАО ап
# ZVEZ         ЗВЕЗДА       0.1          -                   ЗВЕЗДА ОАО ао
#
#        Капитализация           Тип   Количество      ISIN-код Гос. регномер  \
# TICKER
# ABRD     19,45 млрд.  Обыкновенная  9.80002e+07  RU000A0JS5T7             -
# ACKO               -  Обыкновенная            -  RU000A0JXS91             -
# AFKS    226,88 млрд.  Обыкновенная     9.65e+09  RU000A0DQZE3             -
# AFLT     73,98 млрд.  Обыкновенная  1.22767e+09  RU0009062285             -
# AGRO               .  Обыкновенная            0  US7496552057             -
# ...              ...           ...          ...           ...           ...
# YRSBP    407,91 млн.  Обыкновенная  4.50732e+06  RU000A0D88B3             -
# ZILL      6,66 млрд.  Обыкновенная  2.65996e+06  RU0009086193             -
# ZMZN      1,91 млрд.  Обыкновенная  1.12734e+08  RU0009101539             -
# ZMZNP       481 млн.  Обыкновенная  3.75781e+07  RU0006752854             -
# ZVEZ      2,45 млрд.  Обыкновенная   5.6202e+08  RU0009091300             -
#
#                        Отрасль  \
# TICKER
# ABRD                   Финансы
# ACKO                   Финансы
# AFKS    Потребительский сектор
# AFLT                 Транспорт
# AGRO                    Прочее
# ...                        ...
# YRSBP        Электроэнергетика
# ZILL            Машиностроение
# ZMZN            Машиностроение
# ZMZNP           Машиностроение
# ZVEZ                    Прочее
#
#                                                  Описание
# TICKER
# ABRD    Завод шампанских вин «Абрау-Дюрсо» — крупнейши...
# ACKO    Страховая компания «ЮЖУРАЛ-АСКО» основана 15 м...
# AFKS    АФК «Система» является одной из самых крупных ...
# AFLT    ПАО «Аэрофлот» — крупнейший авиаперевозчик Рос...
# AGRO    Группа Компаний «РУСАГРО» - это крупнейший вер...
# ...                                                   ...
# YRSBP   ПАО «ТНС энерго Ярославль» (до 30 июня 2015 го...
# ZILL    ООО ЗИЛ (Завод имени Лихачёва) — одна из старе...
# ZMZN    ПАО «ЗМЗ» — один из крупнейших российских прои...
# ZMZNP   ПАО «ЗМЗ» — один из крупнейших российских прои...
# ZVEZ    ПАО "ЗВЕЗДА" - крупнейший в России производите...
#
# [284 rows x 11 columns]

# %%
heads
# Out:
#                actual_time  actual_price  pct_change_tod     open  \
# TICKER
# ABRD   2020-10-09 18:45:00       198.500            0.00   195.00
# ACKO   2020-10-09 18:37:00         4.960            0.00     4.96
# AFKS   2020-10-09 23:49:00        23.511           -1.00    23.75
# AFLT   2020-10-09 23:49:00        60.260           -3.92    60.66
# AGRO   2020-10-09 18:45:00       739.000           -0.67   745.00
# ...                    ...           ...             ...      ...
# YRSBP  2020-10-08 18:01:00        90.500            0.56    90.00
# ZILL   2020-10-09 18:37:00      2505.000           -0.40  2475.00
# ZMZN   2020-10-12 00:00:00        16.900            0.00    17.20
# ZMZNP  2020-10-12 00:00:00        12.800           -7.25    12.80
# ZVEZ   2020-10-09 18:17:00         4.355           -1.02     4.40
#
#        close_prev_day        volume max_price_ytd min_price_ytd  \
# TICKER
# ABRD            198.5  2.081150e+06         202.5           195
# ACKO             4.96  5.127600e+04          5.04          4.96
# AFKS           23.748  7.852769e+08        24.117        23.517
# AFLT            62.72  6.650002e+09         64.92          61.8
# AGRO              744  4.620441e+07         761.6           730
# ...               ...           ...           ...           ...
# YRSBP              90  2.322000e+04            93          86.5
# ZILL             2515  9.960000e+03          2530          2480
# ZMZN             16.9  2.402000e+03          17.3          16.9
# ZMZNP            13.8  1.280000e+03          13.8            13
# ZVEZ              4.4  2.801950e+05         4.445           4.4
#
#         pct_change_ytd pct_change_month pct_change_year
# TICKER
# ABRD              1.28            -2.93           48.13
# ACKO             -0.40             -0.8            7.36
# AFKS              1.03             13.7           85.74
# AFLT             -4.77           -26.49          -39.75
# AGRO              1.67             1.23            7.91
# ...                ...              ...             ...
# YRSBP             4.65             3.43            5.85
# ZILL              0.40             1.01           51.82
# ZMZN             -3.98                0               0
# ZMZNP             7.81                0               0
# ZVEZ             -0.11            -6.04           -5.94
#
# [284 rows x 11 columns]

# %%
divs
# Out:
#                     company_name_period      last_day_to_buy  \
# TICKER
# ABRD    Абрау-Дюрсо ао нераспр. прибыль  2016-11-16 00:00:00
# ABRD              Абрау – Дюрсо ао 2016  2017-06-28 00:00:00
# ABRD              Абрау – Дюрсо ао 2017  2018-06-22 00:00:00
# ABRD              Абрау – Дюрсо ао 2018  2019-07-08 00:00:00
# ABRD                Абрау-Дюрсо ао 2019  2020-10-15 00:00:00
# ...                                 ...                  ...
# YAKG                       ЯТЭК ао 2016                  NaT
# YKEN               Якутскэнерго ао 2010
# YKEN               Якутскэнерго ао 2011
# YKENP              Якутскэнерго ап 2010  2011-04-14 00:00:00
# YKENP              Якутскэнерго ап 2011  2012-05-12 00:00:00
#
#                  close_date       value   price profit_pct
# TICKER
# ABRD    2016-11-19 00:00:00        0.41      88       0.47
# ABRD    2017-07-02 00:00:00        1.29     200       0.65
# ABRD    2018-06-26 00:00:00        2.86     147       1.95
# ABRD    2019-07-10 00:00:00        2.86     142       2.01
# ABRD    2020-10-19 00:00:00        1.03   198.5       0.52
# ...                     ...         ...     ...        ...
# YAKG                    NaT           0
# YKEN    2011-04-14 00:00:00           0                  0
# YKEN    2012-05-12 00:00:00           0                  0
# YKENP   2011-04-14 00:00:00  0.00939045   0.485       1.94
# YKENP   2012-05-12 00:00:00   0.0100441  0.3472       2.89
#
# [1799 rows x 6 columns]

# %%
# clean cache
for fname in os.listdir(base_path):
    rm_path = os.path.join(base_path, fname)
    print('remove:', rm_path)
    os.remove(rm_path)
